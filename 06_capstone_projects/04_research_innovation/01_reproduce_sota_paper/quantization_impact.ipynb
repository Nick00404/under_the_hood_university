# %%
# quantization_impact.ipynb

# ---------------------
# 1. Setup and Imports
# ---------------------
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import time
import os
import gc

torch.set_default_dtype(torch.float32)  # Avoid AMP/FP16 for now

# --------------------------
# 2. Model Loading (Change this line to use your own model)
# --------------------------
model_name = "EleutherAI/pythia-410m"  # Swap this with Mistral or any custom model

tokenizer = AutoTokenizer.from_pretrained(model_name)
model_fp32 = AutoModelForCausalLM.from_pretrained(model_name)
model_fp32.eval()

# Move to CPU for quantization work
device = torch.device("cpu")
model_fp32.to(device)

# --------------------------
# 3. Define Inference Helper
# --------------------------
def run_inference(model, prompt, max_new_tokens=20):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    start = time.time()
    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=max_new_tokens)
    end = time.time()
    return tokenizer.decode(outputs[0], skip_special_tokens=True), end - start

# --------------------------
# 4. Baseline FP32 Inference
# --------------------------
prompt = "The singularity is near because"
output_fp32, time_fp32 = run_inference(model_fp32, prompt)

print("📦 FP32 Inference Output:", output_fp32)
print("⏱️ FP32 Inference Time: {:.3f}s".format(time_fp32))

# --------------------------
# 5. Apply Dynamic Quantization
# --------------------------
model_dynamic = torch.quantization.quantize_dynamic(
    model_fp32, {torch.nn.Linear}, dtype=torch.qint8
)

output_dynamic, time_dynamic = run_inference(model_dynamic, prompt)

print("📦 Dynamic Quantized Output:", output_dynamic)
print("⏱️ Dynamic Quantized Time: {:.3f}s".format(time_dynamic))

# --------------------------
# 6. Compare Model Sizes
# --------------------------
def get_model_size(model, name="temp.pt"):
    torch.save(model.state_dict(), name)
    size_mb = os.path.getsize(name) / 1e6
    os.remove(name)
    return size_mb

size_fp32 = get_model_size(model_fp32)
size_dynamic = get_model_size(model_dynamic)

print("📉 Model Size (FP32): {:.2f} MB".format(size_fp32))
print("📉 Model Size (Dynamic Q): {:.2f} MB".format(size_dynamic))

# --------------------------
# 7. Optional: Post-Training Static Quantization (Experimental)
# --------------------------
# Static quantization requires fusion + calibration dataset. Recommended only after full model prep.
# Placeholder for future QAT or calibration steps.

# --------------------------
# 8. Summary Report
# --------------------------
print("\n🧠 Summary")
print(f"Accuracy proxy (output match): {'Same' if output_fp32 == output_dynamic else 'Different'}")
print(f"Latency reduction: {((time_fp32 - time_dynamic) / time_fp32) * 100:.2f}%")
print(f"Model size reduction: {((size_fp32 - size_dynamic) / size_fp32) * 100:.2f}%")

# --------------------------
# 9. Cleanup
# --------------------------
del model_fp32, model_dynamic
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       1 # quantization_impact.ipynb
#       2
#       3 # ---------------------
#       4 # 1. Setup and Imports
#       5 # ---------------------
#       6 import torch
# ----> 7 from transformers import AutoModelForCausalLM, AutoTokenizer
#       8 import time
#       9 import os
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\import_utils.py:1965, in _LazyModule.__getattr__(self, name)
#    1963 elif name in self._class_to_module.keys():
#    1964     module = self._get_module(self._class_to_module[name])
# -> 1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#    1967     value = self._get_module(name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1962     value = Placeholder
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1974 def _get_module(self, module_name: str):
#    1975     try:
# -> 1976         return importlib.import_module("." + module_name, self.__name__)
#    1977     except Exception as e:
#    1978         raise RuntimeError(
#    1979             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980             f" traceback):\n{e}"
#    1981         ) from e
#
# File c:\Program Files\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\auto\modeling_auto.py:22
#      20 from ...configuration_utils import PretrainedConfig
#      21 from ...utils import logging
# ---> 22 from .auto_factory import (
#      23     _BaseAutoBackboneClass,
#      24     _BaseAutoModelClass,
#      25     _LazyAutoMapping,
#      26     auto_class_update,
#      27 )
#      28 from .configuration_auto import CONFIG_MAPPING_NAMES
#      31 logger = logging.get_logger(__name__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\auto\auto_factory.py:40
#      36 from .configuration_auto import AutoConfig, model_type_to_module_name, replace_list_option_in_docstrings
#      39 if is_torch_available():
# ---> 40     from ...generation import GenerationMixin
#      43 logger = logging.get_logger(__name__)
#      46 CLASS_DOCSTRING = """
#      47     This is a generic model class that will be instantiated as one of the model classes of the library when created
#      48     with the [`~BaseAutoModelClass.from_pretrained`] class method or the [`~BaseAutoModelClass.from_config`] class
#    (...)     51     This class cannot be instantiated directly using `__init__()` (throws an error).
#      52 """
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1962     value = Placeholder
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\utils\import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1974 def _get_module(self, module_name: str):
#    1975     try:
# -> 1976         return importlib.import_module("." + module_name, self.__name__)
#    1977     except Exception as e:
#    1978         raise RuntimeError(
#    1979             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980             f" traceback):\n{e}"
#    1981         ) from e
#
# File c:\Program Files\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\generation\utils.py:30
#      27 from torch import nn
#      28 from torch.nn import functional as F
# ---> 30 from transformers.generation.candidate_generator import AssistantVocabTranslatorCache
#      32 from ..cache_utils import (
#      33     Cache,
#      34     DynamicCache,
#    (...)     38     StaticCache,
#      39 )
#      40 from ..configuration_utils import PretrainedConfig
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\generation\candidate_generator.py:27
#      23 from ..utils import is_sklearn_available
#      26 if is_sklearn_available():
# ---> 27     from sklearn.metrics import roc_curve
#      29 from ..cache_utils import DynamicCache
#      30 from ..pytorch_utils import isin_mps_friendly
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\__init__.py:6
#       1 """Score functions, performance metrics, pairwise metrics and distance computations."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from . import cluster
#       7 from ._classification import (
#       8     accuracy_score,
#       9     balanced_accuracy_score,
#    (...)     27     zero_one_loss,
#      28 )
#      29 from ._dist_metrics import DistanceMetric
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\cluster\__init__.py:12
#       8 # Authors: The scikit-learn developers
#       9 # SPDX-License-Identifier: BSD-3-Clause
#      11 from ._bicluster import consensus_score
# ---> 12 from ._supervised import (
#      13     adjusted_mutual_info_score,
#      14     adjusted_rand_score,
#      15     completeness_score,
#      16     contingency_matrix,
#      17     entropy,
#      18     expected_mutual_information,
#      19     fowlkes_mallows_score,
#      20     homogeneity_completeness_v_measure,
#      21     homogeneity_score,
#      22     mutual_info_score,
#      23     normalized_mutual_info_score,
#      24     pair_confusion_matrix,
#      25     rand_score,
#      26     v_measure_score,
#      27 )
#      28 from ._unsupervised import (
#      29     calinski_harabasz_score,
#      30     davies_bouldin_score,
#      31     silhouette_samples,
#      32     silhouette_score,
#      33 )
#      35 __all__ = [
#      36     "adjusted_mutual_info_score",
#      37     "normalized_mutual_info_score",
#    (...)     54     "consensus_score",
#      55 ]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\cluster\_supervised.py:22
#      20 from ...utils.multiclass import type_of_target
#      21 from ...utils.validation import check_array, check_consistent_length
# ---> 22 from ._expected_mutual_info_fast import expected_mutual_information
#      25 def check_clusterings(labels_true, labels_pred):
#      26     """Check that the labels arrays are 1D and of same dimension.
#      27
#      28     Parameters
#    (...)     34         The predicted labels.
#      35     """
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
