# %% [markdown]
# ### **01_lime_intro.ipynb**
#
# 1. **Introduction to LIME (Local Interpretable Model-agnostic Explanations)**
#    - What is LIME and why use it?
#    - Local interpretability vs global
#    - Comparison to SHAP and other techniques
#
# 2. **Core Concepts of LIME**
#    - Local surrogate models
#    - Perturbation sampling and weighting
#    - Interpretable space vs original feature space
#
# 3. **Installing and Importing LIME**
#    - Required packages
#    - Importing `lime.lime_tabular`, `lime.lime_text`
#
# 4. **Preparing Data for LIME**
#    - Fitting a model (e.g., Logistic Regression or Random Forest)
#    - Feature formatting (numerical + categorical handling)
#    - Dataset scaling and preprocessing compatibility
#
# 5. **Explaining Tabular Models**
#    - Creating a `LimeTabularExplainer`
#    - Generating explanations for single predictions
#    - Interpreting the explanation object
#
# 6. **Visualizing LIME Results**
#    - HTML explanation viewer
#    - Feature weight bar plots
#    - Exporting explanations as images or text
#
# ---
#
# ### **02_text_and_tabular.ipynb**
#
# 1. **Text Data and LIME**
#    - Working with `LimeTextExplainer`
#    - Tokenization and word importance
#    - Visualizing word-based explanations
#    - Explaining sentiment or classification tasks
#
# 2. **Handling Multi-class Problems**
#    - Specifying `labels` in explainer
#    - Understanding class probabilities
#    - Generating explanations for specific classes
#
# 3. **Comparing Interpretability Techniques**
#    - LIME vs SHAP for tabular data
#    - Strengths and limitations of LIME
#    - Use cases where LIME is preferable (e.g., text data)
#
# 4. **Customizing LIME Behavior**
#    - Distance metrics for locality
#    - Kernel width and sample size tuning
#    - Feature selection strategies
#
# 5. **Batch Explanation Workflows**
#    - Looping over multiple samples
#    - Aggregating local explanations
#    - Embedding explanations into dashboards
#
# 6. **Limitations and Best Practices**
#    - Stability and consistency challenges
#    - Risks of misinterpretation
#    - Performance on high-dimensional data
